# %% [markdown]
# Fig. 2E

# %%
suppressPackageStartupMessages({
    library(ggplot2)
    library(stringr)
    library(Seurat)
    library(dplyr)
    library(SingleCellExperiment)
    library(SummarizedExperiment)
    library(HDF5Array)
    library(DelayedArray)
    library(Matrix)
    library(showtext)
    library(sysfonts)

# Download Roboto from Google Font, which is same as in Biorender
font_add_google("Roboto", "roboto")

# Enable showtext rendering
showtext_auto()

# Optional: set a default theme with Roboto for all plots
theme_set(theme_grey(base_family = "roboto") +
          theme( text = element_text(color = "black"))
          )
})
set.seed(100)

# %%
WD <- "data/"
sample <- "raw_counts_SELECTseq_200000.rds"
adata <- readRDS(paste0(WD, sample))
adata
# Out:
# An object of class Seurat
# 31360 features across 252 samples within 1 assay
# Active assay: RNA (31360 features, 0 variable features)
#  2 layers present: counts, data

# %%
options(repr.plot.width = 6, repr.plot.height =7)
df <- adata@meta.data
df$cell_line <- factor(df$cell_line, levels = c("U2OS", "T47D"))
df$sample_group <- factor(df$sample_group, levels = c("U2OS_PIKnocrRNA", "U2OS_PIKcrRNA1", "U2OS_PIKcrRNA4", "T47D_PIKnocrRNA", "T47D_PIKcrRNA1", "T47D_PIKcrRNA4"))

ggplot(df, aes(x = sample_group, y = nFeature_RNA, fill = cell_line)) +
  

  geom_violin(trim = TRUE, alpha = 0.6, color = NA) +

  geom_boxplot(width = 0.2,
               outlier.shape = NA,
               alpha = 1,
               color = "black",
               linewidth = 0.4) +

  scale_fill_manual(values = c("U2OS" = "#E69F00",
                               "T47D" = "#56B4E9"),
                    labels = c(
      "U2OS" = "U-2 OS",
      "T47D" = "T-47D")) +

  labs(
    x = "",
    y = "Genes detected per cell"
  ) +

  theme_bw(base_size = 16) +
  theme(
    plot.title = element_text(hjust = 0.5, face = "bold"),
    axis.text.x = element_text(size = 18, color = "black", angle = 90),
    axis.text.y = element_text(size = 18, color = "black"),
    axis.ticks.x = element_blank(),
    axis.ticks.y = element_line(linewidth = 0.75),
    axis.title.y = element_text(size = 20, margin = margin(r = 15)),
    legend.position = c(0.5, 0.96),
    panel.grid = element_blank(),
    panel.border = element_blank(),
    axis.line = element_line(color = "black", linewidth = 0.75),
    legend.title = element_blank(),
    legend.direction = "horizontal",
    legend.text = element_text(size = 18)
  ) +
  ylim(0,5000)
# Out:
# Warning message:
# “A numeric `legend.position` argument in `theme()` was deprecated in ggplot2
# 3.5.0.
# ℹ Please use the `legend.position.inside` argument of `theme()` instead.”
# plot without title

# %%
table(df$sample_group)
# Out:
# U2OS_PIKnocrRNA  U2OS_PIKcrRNA1  U2OS_PIKcrRNA4 T47D_PIKnocrRNA  T47D_PIKcrRNA1
#              39              46              42              40              42
#  T47D_PIKcrRNA4
#              43

# %%
sessionInfo()
# Out:
# R version 4.3.3 (2024-02-29)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Ubuntu 22.04.5 LTS
#
# Matrix products: default
# BLAS/LAPACK: /software/cellgen/team205/si9/envs/Seurat/lib/libopenblasp-r0.3.28.so;  LAPACK version 3.12.0
#
# locale:
#  [1] LC_CTYPE=C.UTF-8    LC_NUMERIC=C        LC_TIME=C
#  [4] LC_COLLATE=C        LC_MONETARY=C       LC_MESSAGES=C
#  [7] LC_PAPER=C          LC_NAME=C           LC_ADDRESS=C
# [10] LC_TELEPHONE=C      LC_MEASUREMENT=C    LC_IDENTIFICATION=C
#
# time zone: Europe/London
# tzcode source: system (glibc)
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] showtext_0.9-7              showtextdb_3.0
#  [3] sysfonts_0.8.9              HDF5Array_1.30.1
#  [5] rhdf5_2.46.1                DelayedArray_0.28.0
#  [7] SparseArray_1.2.4           S4Arrays_1.2.1
#  [9] abind_1.4-8                 Matrix_1.6-5
# [11] SingleCellExperiment_1.24.0 SummarizedExperiment_1.32.0
# [13] Biobase_2.62.0              GenomicRanges_1.54.1
# [15] GenomeInfoDb_1.38.8         IRanges_2.36.0
# [17] S4Vectors_0.40.2            BiocGenerics_0.48.1
# [19] MatrixGenerics_1.14.0       matrixStats_1.5.0
# [21] dplyr_1.1.4                 Seurat_5.3.0
# [23] SeuratObject_5.2.0          sp_2.2-0
# [25] stringr_1.5.2               ggplot2_3.5.2
#
# loaded via a namespace (and not attached):
#   [1] RColorBrewer_1.1-3      jsonlite_2.0.0          magrittr_2.0.4
#   [4] spatstat.utils_3.2-0    farver_2.1.2            zlibbioc_1.48.2
#   [7] ragg_1.3.3              vctrs_0.6.5             ROCR_1.0-11
#  [10] Cairo_1.6-3             spatstat.explore_3.5-3  RCurl_1.98-1.17
#  [13] base64enc_0.1-3         htmltools_0.5.8.1       curl_7.0.0
#  [16] Rhdf5lib_1.24.2         sctransform_0.4.2       parallelly_1.45.1
#  [19] KernSmooth_2.23-26      htmlwidgets_1.6.4       ica_1.0-3
#  [22] plyr_1.8.9              plotly_4.11.0           zoo_1.8-14
#  [25] uuid_1.2-1              igraph_2.1.4            mime_0.13
#  [28] lifecycle_1.0.4         pkgconfig_2.0.3         R6_2.6.1
#  [31] fastmap_1.2.0           GenomeInfoDbData_1.2.11 fitdistrplus_1.2-4
#  [34] future_1.67.0           shiny_1.11.1            digest_0.6.37
#  [37] patchwork_1.3.2         tensor_1.5.1            RSpectra_0.16-2
#  [40] irlba_2.3.5.1           textshaping_1.0.0       labeling_0.4.3
#  [43] progressr_0.16.0        spatstat.sparse_3.1-0   httr_1.4.7
#  [46] polyclip_1.10-7         compiler_4.3.3          withr_3.0.2
#  [49] fastDummies_1.7.5       MASS_7.3-60.0.1         tools_4.3.3
#  [52] lmtest_0.9-40           httpuv_1.6.16           future.apply_1.20.0
#  [55] goftest_1.2-3           glue_1.8.0              rhdf5filters_1.14.1
#  [58] nlme_3.1-168            promises_1.3.3          grid_4.3.3
#  [61] pbdZMQ_0.3-13           Rtsne_0.17              cluster_2.1.8.1
#  [64] reshape2_1.4.4          generics_0.1.4          gtable_0.3.6
#  [67] spatstat.data_3.1-8     tidyr_1.3.1             data.table_1.17.8
#  [70] XVector_0.42.0          spatstat.geom_3.6-0     RcppAnnoy_0.0.22
#  [73] ggrepel_0.9.6           RANN_2.6.2              pillar_1.11.1
#  [76] spam_2.11-1             IRdisplay_1.1           RcppHNSW_0.6.0
#  [79] later_1.4.4             splines_4.3.3           lattice_0.22-6
#  [82] survival_3.8-3          deldir_2.0-4            tidyselect_1.2.1
#  [85] miniUI_0.1.2            pbapply_1.7-4           gridExtra_2.3
#  [88] scattermore_1.2         stringi_1.8.7           lazyeval_0.2.2
#  [91] evaluate_1.0.5          codetools_0.2-20        tibble_3.3.0
#  [94] cli_3.6.5               uwot_0.2.3              IRkernel_1.3.2
#  [97] xtable_1.8-4            reticulate_1.43.0       systemfonts_1.1.0
# [100] repr_1.1.7              Rcpp_1.1.0              globals_0.18.0
# [103] spatstat.random_3.4-2   png_0.1-8               spatstat.univar_3.1-4
# [106] parallel_4.3.3          dotCall64_1.2           bitops_1.0-9
# [109] listenv_0.9.1           viridisLite_0.4.2       scales_1.4.0
# [112] ggridges_0.5.7          purrr_1.1.0             crayon_1.5.3
# [115] rlang_1.1.6             cowplot_1.2.0
